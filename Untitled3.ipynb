# %%
import json
import lzma
import numpy as np
import os
import pandas as pd
import regex as re
import tarfile
import zipfile
from io import StringIO
from os import listdir as ls
from pandas import DataFrame as df
from tqdm import tqdm
from typing import Union
from unidecode import unidecode
from os.path import basename as bname
from os.path import dirname as dname
from os.path import expanduser as xpu
from os.path import join as pjoin
from os.path import normcase as nc
from tarfile import TarFile

# archvpath = "~/../../media/francois/seagate_1tb/large_files/Python-3.9.1.tar.xz"
archvpath = "~/../../data/simexp/datasets/cimaq_20190901/"
ls(xpu(archvpath))
# Out:
# ['sub-5522727',
#  'sub-4460076',
#  'sub-4932877',
#  'sub-5359706',
#  'sub-7435733',
#  'sub-5381177',
#  'sub-3708747',
#  'sub-4050235',
#  'sub-9259807',
#  'sub-9494076',
#  'sub-5038758',
#  'sub-6023087',
#  'sub-6417837',
#  'sub-4694616',
#  'sub-4398745',
#  'sub-4799805',
#  'sub-5317128',
#  'sub-4344061',
#  'sub-9417188',
#  'sub-7113680',
#  'sub-5375537',
#  'sub-7948407',
#  'sub-7955836',
#  'sub-3239082',
#  'sub-5717179',
#  'sub-5348754',
#  'sub-7729270',
#  'sub-5028259',
#  'sub-3886505',
#  'sub-8193847',
#  'sub-7241882',
#  'sub-4117134',
#  'sub-7674650',
#  'sub-4548020',
#  'sub-3420680',
#  'sub-8875385',
#  'sub-5595871',
#  'sub-4557550',
#  'sub-3885925',
#  'sub-3874544',
#  'sub-7661810',
#  'sub-3750063',
#  'sub-3025432',
#  'sub-8278658',
#  'sub-9249304',
#  'sub-5912532',
#  'sub-8060583',
#  'sub-7720517',
#  'sub-5485738',
#  'sub-4548797',
#  'sub-4669690',
#  'sub-5661505',
#  'sub-4475292',
#  'sub-5057190',
#  'sub-8352112',
#  'sub-4219281',
#  'sub-3702154',
#  'sub-3123186',
#  'sub-8782079',
#  'sub-4118813',
#  'sub-8758136',
#  'sub-6957814',
#  'sourcedata',
#  'sub-7725018',
#  'sub-4489559',
#  'sub-5760364',
#  'sub-4206804',
#  'sub-5679978',
#  'sub-6272511',
#  'sub-3002498',
#  'sub-7568100',
#  'sub-5477234',
#  'sub-8330218',
#  'sub-4810652',
#  'sub-4893763',
#  'sub-9322528',
#  'sub-8639515',
#  'sub-6258913',
#  'sub-7424803',
#  'sub-6741996',
#  'sub-3956111',
#  'sub-9234862',
#  'sub-4084560',
#  'dataset_description.json',
#  'sub-4315114',
#  'sub-3494204',
#  'sub-7853010',
#  'sub-6027529',
#  'sub-3464550',
#  'sub-6841569',
#  'sub-5195562',
#  'sub-6427603',
#  'sub-8656527',
#  'sub-3970362',
#  'sub-3980811',
#  'sub-8980899',
#  'sub-3963780',
#  'sub-5476142',
#  '.gitattributes',
#  'sub-5909569',
#  'sub-4262024',
#  '.datalad',
#  'sub-8192087',
#  'sub-4273359',
#  'sub-4292802',
#  'sub-3291977',
#  'sub-3865361',
#  'sub-7707569',
#  'sub-3163875',
#  'sub-3967609',
#  'sub-8923536',
#  'sub-6281721',
#  'sub-3400972',
#  'sub-6645963',
#  'sub-7874568',
#  'sub-8697622',
#  'sub-9003010',
#  'sub-5237572',
#  'sub-7086941',
#  'sub-7485585',
#  'sub-4013119',
#  'sub-7308293',
#  'sub-6051205',
#  'sub-5440497',
#  'sub-3186603',
#  'sub-7274924',
#  'sub-8212673',
#  'sub-3589314',
#  'sub-5788838',
#  'sub-3149469',
#  'sub-7459501',
#  'sub-7947166',
#  'sub-3514091',
#  'sub-6511952',
#  'sub-4509950',
#  'sub-4331322',
#  'sub-5089797',
#  'sub-4501657',
#  'sub-7516889',
#  'sub-3988228',
#  'sub-6481936',
#  'sub-9296157',
#  'sub-7543023',
#  'sub-9648306',
#  'sub-8874623',
#  'sub-3801419',
#  'sub-4576408',
#  'sub-8069157',
#  'sub-5701721',
#  'sub-4688294',
#  'sub-6003672',
#  'sub-6334263',
#  'sub-3431566',
#  'sub-5685939',
#  'sub-8822770',
#  'sub-4051959',
#  'sub-6121388',
#  'sub-8600790',
#  'sub-8724977',
#  'sub-7538204',
#  'sub-6168985',
#  'sub-8827943',
#  'sub-4316663',
#  'sub-4835330',
#  'sub-8734231',
#  'sub-7712552',
#  'sub-8167576',
#  '.git',
#  'sub-3572536',
#  'sub-6274286',
#  'sub-6421082',
#  'sub-7256003',
#  'code',
#  'sub-3303819',
#  'sub-5296375',
#  'sub-6633412',
#  'sub-7573547',
#  'sub-7169162',
#  'sub-4789411',
#  'sub-6120847',
#  'sub-4487561',
#  'sub-7060373',
#  'sub-9929164',
#  'sub-6479756']
