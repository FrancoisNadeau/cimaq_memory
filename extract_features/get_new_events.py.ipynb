# %% [markdown]
# # get_new_events.py Explained
#
# ### Conversion of step 2 in CIMAQ_getBetaMaps.ipynb
# ### as to executable python script
#
# ### Transition from Nistats to Nilearn modules

# %% [markdown]
# ## Set-up and visualization of initial files

# %%
import glob
import nibabel
import nilearn
import numpy as np
import os
import pandas as pd
import scipy
import sys

from matplotlib import pyplot as plt
from nilearn.plotting import plot_design_matrix
from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.first_level import make_first_level_design_matrix
from nilearn import image
from nilearn import plotting
from nilearn.plotting import plot_stat_map, plot_anat, plot_img, show
from numpy import nan as NaN
from os import listdir as ls
from os.path import basename as bname
from os.path import dirname as dname
from os.path import join
from pandas import DataFrame as df
from cimaq_utils import loadimages
from get_new_events import get_new_events
from pandas import DataFrame as df

taskfilesdir = os.path.expanduser("~/../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed")
outTask_dir = os.path.expanduser("~/cimaq_memory/NEW_task_files")
taskfiles = [(os.path.splitext(bname(file))[0], pd.read_csv(join(taskfilesdir, file), sep='\t'))
             for file in ls(taskfilesdir) if "events" in file and file.endswith(".tsv")]
print(len(taskfiles))
# get_new_events(taskfilesdir= "~/../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed",
#                    outTask_dir="~/cimaq_memory/NEW_task_files",
#                   savefiles=False)
display(taskfiles[0][0], taskfiles[0][1],
       taskfiles[50][0], taskfiles[50][1],
       taskfiles[102][0], taskfiles[102][1])
# Out:
# 103
# 'sub-804743_ses-4_task-memory_events'
#      trial_number    onset  duration   offset trial_type  response  \
# 0               4   16.076     3.000   19.076        CTL       NaN
# 1               5   20.076     3.000   23.076        Enc       NaN
# 2               6   31.075     3.000   34.075        Enc       NaN
# 3               7   41.574     3.000   44.574        Enc       NaN
# 4               8   45.074     3.000   48.074        Enc       NaN
# ..            ...      ...       ...      ...        ...       ...
# 112           116  713.522     2.999  716.521        CTL       NaN
# 113           117  721.021     3.000  724.021        CTL       NaN
# 114           118  724.521     3.000  727.521        Enc       NaN
# 115           119  731.520     3.000  734.520        Enc       NaN
# 116           120  735.520     3.000  738.520        Enc       NaN
#
#      response_time stim_id stim_file stim_category          stim_name  \
# 0              0.0     NaN      None          None               None
# 1              0.0   Old64      None      sporting     snow shoes_old
# 2              0.0   Old10      None        animal            penguin
# 3              0.0   Old61      None      sporting    mini-trampoline
# 4              0.0   Old43      None       musical           harp_new
# ..             ...     ...       ...           ...                ...
# 112            0.0     NaN      None          None               None
# 113            0.0     NaN      None          None               None
# 114            0.0   Old54      None      sporting  Badminton Racquet
# 115            0.0   Old28      None       kitchen    big cooking pot
# 116            0.0   Old25      None          food         shellpasta
#
#      recognition_accuracy  recognition_responsetime  position_correct  \
# 0                      -1                       NaN                 6
# 1                       1                     1.328                 8
# 2                       1                     1.146                 5
# 3                       1                     1.434                 5
# 4                       1                     1.377                 6
# ..                    ...                       ...               ...
# 112                    -1                       NaN                 8
# 113                    -1                       NaN                 9
# 114                     1                     1.642                 6
# 115                     0                     1.357                 5
# 116                     1                     1.993                 6
#
#      position_response  position_accuracy  position_responsetime
# 0                 -1.0                 -1                    NaN
# 1                  8.0                  2                  0.317
# 2                  5.0                  2                  0.285
# 3                  5.0                  2                  1.855
# 4                  6.0                  2                  1.350
# ..                 ...                ...                    ...
# 112               -1.0                 -1                    NaN
# 113               -1.0                 -1                    NaN
# 114                6.0                  2                  0.652
# 115               -1.0                  0                    NaN
# 116                6.0                  2                  0.745
#
# [117 rows x 17 columns]
# 'sub-920577_ses-4_task-memory_events'
#      trial_number    onset  duration   offset trial_type  response  \
# 0               4   14.566     3.000   17.566        Enc       NaN
# 1               5   24.066     2.999   27.065        Enc       NaN
# 2               6   29.065     3.000   32.065        Enc       NaN
# 3               7   33.565     2.999   36.564        Enc       NaN
# 4               8   37.564     3.000   40.564        Enc       NaN
# ..            ...      ...       ...      ...        ...       ...
# 112           116  710.004     3.000  713.004        Enc       NaN
# 113           117  717.504     2.999  720.503        Enc       NaN
# 114           118  726.003     3.000  729.003        Enc       NaN
# 115           119  730.002     3.000  733.002        Enc       NaN
# 116           120  733.502     3.000  736.502        Enc       NaN
#
#      response_time stim_id stim_file stim_category        stim_name  \
# 0              0.0   Old60      None      sporting  karate clothing
# 1              0.0   Old07      None        animal         lion_new
# 2              0.0   Old17      None          food    chocolatemilk
# 3              0.0   Old70      None         fruit    pineapple_old
# 4              0.0   Old64      None      sporting   snow shoes_old
# ..             ...     ...       ...           ...              ...
# 112            0.0   Old45      None       musical      double bass
# 113            0.0   Old50      None       musical             tuba
# 114            0.0   Old23      None          food       rawchicken
# 115            0.0   Old28      None       kitchen  big cooking pot
# 116            0.0   Old26      None          food            toast
#
#      recognition_accuracy  recognition_responsetime  position_correct  \
# 0                       0                     4.313                 6
# 1                       0                     3.895                 5
# 2                       0                     1.707                 6
# 3                       0                     2.472                 9
# 4                       0                     2.058                 8
# ..                    ...                       ...               ...
# 112                     0                     2.408                 5
# 113                     1                     1.977                 6
# 114                     0                     1.716                 5
# 115                     1                     2.474                 5
# 116                     0                     1.631                 8
#
#      position_response  position_accuracy  position_responsetime
# 0                   -1                  0                    NaN
# 1                   -1                  0                    NaN
# 2                   -1                  0                    NaN
# 3                   -1                  0                    NaN
# 4                   -1                  0                    NaN
# ..                 ...                ...                    ...
# 112                 -1                  0                    NaN
# 113                  8                  1                  1.064
# 114                 -1                  0                    NaN
# 115                  5                  2                  0.654
# 116                 -1                  0                    NaN
#
# [117 rows x 17 columns]
# 'sub-199801_ses-4_task-memory_events'
#      trial_number    onset  duration   offset trial_type  response  \
# 0               4   16.099     2.999   19.098        CTL       2.0
# 1               5   20.098     3.000   23.098        Enc       2.0
# 2               6   31.097     3.000   34.097        Enc       2.0
# 3               7   41.597     2.999   44.596        Enc       2.0
# 4               8   45.096     3.000   48.096        Enc       2.0
# ..            ...      ...       ...      ...        ...       ...
# 112           116  713.544     3.000  716.544        CTL       2.0
# 113           117  721.043     3.000  724.043        CTL       2.0
# 114           118  724.543     3.000  727.543        Enc       2.0
# 115           119  731.542     3.000  734.542        Enc       2.0
# 116           120  735.542     3.000  738.542        Enc       2.0
#
#      response_time stim_id stim_file stim_category            stim_name  \
# 0            1.205     NaN      None          None                 None
# 1            1.139   Old54      None      sporting    Badminton Racquet
# 2            1.770   Old01      None        animal            camel_new
# 3            1.881   Old59      None      sporting          fishing rod
# 4            2.393   Old42      None       musical  acoustic guitar_new
# ..             ...     ...       ...           ...                  ...
# 112          0.808     NaN      None          None                 None
# 113          0.957     NaN      None          None                 None
# 114          1.129   Old53      None      sporting     americanfootball
# 115          1.566   Old30      None       kitchen        cookie cutter
# 116          1.165   Old22      None          food            pickle01a
#
#      recognition_accuracy  recognition_responsetime  position_correct  \
# 0                      -1                       NaN                 6
# 1                       1                     1.912                 8
# 2                       1                     1.167                 5
# 3                       1                     1.610                 5
# 4                       1                     1.572                 6
# ..                    ...                       ...               ...
# 112                    -1                       NaN                 8
# 113                    -1                       NaN                 9
# 114                     1                     3.221                 6
# 115                     1                     1.434                 5
# 116                     1                     1.308                 6
#
#      position_response  position_accuracy  position_responsetime
# 0                 -1.0                 -1                    NaN
# 1                  8.0                  2                  2.058
# 2                  9.0                  1                  1.927
# 3                  9.0                  1                  2.081
# 4                  9.0                  1                  1.117
# ..                 ...                ...                    ...
# 112               -1.0                 -1                    NaN
# 113               -1.0                 -1                    NaN
# 114                6.0                  2                  1.220
# 115                9.0                  1                  1.319
# 116                5.0                  1                  1.630
#
# [117 rows x 17 columns]

# %% [markdown]
# ## 103 participants
# ## 117 memory task trials
# ## 17 attributes for each trial

# %%
# taskfilesdir = os.path.expanduser("~/../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed")
# outTask_dir = os.path.expanduser("~/cimaq_memory/NEW_task_files")

import glob
import nibabel
import nilearn
import numpy as np
import os
import pandas as pd
import scipy
import sys

from matplotlib import pyplot as plt
from nilearn.plotting import plot_design_matrix
from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.first_level import make_first_level_design_matrix
from nilearn import image
from nilearn import plotting
from nilearn.plotting import plot_stat_map, plot_anat, plot_img, show
from numpy import nan as NaN
from os import listdir as ls
from os.path import basename as bname
from os.path import dirname as dname
from os.path import join
from pandas import DataFrame as df
from cimaq_utils import loadimages
from get_new_events import get_new_events
from pandas import DataFrame as df

def main():
    
    def get_new_events(taskfilesdir, outTask_dir, savefiles=False):
        #rename "trial_type" column as "condition"
        taskfiles = [(os.path.splitext(bname(file))[0], pd.read_csv(join(taskfilesdir, file), sep='\t'))
                     for file in ls(taskfilesdir) if "events" in file and file.endswith(".tsv")]
        new_events = []

        for s_task in taskfiles:
        #load counfounds file as pandas dataframe 
        # confounds = pd.read_csv(subject_motion, sep='\t')
        #scan duration, in seconds : number of fMRI frames (~310), times TR = 2.5s
        # scanDur = confounds.shape[0]*2.5
            scanDur = s_task[1].shape[0]*2.5

            s_task[1].rename(columns={'trial_type':'condition'}, inplace=True)

            #add columns to DataFrame
            numCol = s_task[1].shape[1] 
            insertCol = [4, numCol+1, numCol+2, numCol+3]
            colNames = ['trial_type', 'unscanned', 'ctl_miss_hit', 'ctl_miss_ws_cs']
            colVals = ['TBD', 0, 'TBD', 'TBD']
            for i in range(0, len(colNames)):
                s_task[1].insert(loc=insertCol[i], column=colNames[i], value=colVals[i], allow_duplicates=True)

            #The 'unscanned' column flag trials for which no brain data was acquired.
            #The scan's duration is shorter than the trial's offset time
            #(0 = data, 1 = no data)
            for j in s_task[1][s_task[1]['offset']>scanDur].index:
                s_task[1].loc[j, 'unscanned']=1

            #pas trial numbers with zeros (on the left) to preserve trial 
            #temporal order when trials are alphabetized
            s_task[1]['trial_number'] = s_task[1]['trial_number'].astype('object',
                                                                   copy=False)
            for k in s_task[1].index:
                s_task[1].loc[k, 'trial_number'] = str(s_task[1].loc[k, 'trial_number']).zfill(3)

            #trial_type should have a unique entry per row so that each trial 
            #can be modelled as a separate condition
            countEnc = 0
            countCTL = 0
            for m in s_task[1][s_task[1]['condition']=='Enc'].index:
                countEnc = countEnc + 1
                s_task[1].loc[m, 'trial_type'] = 'Enc'+str(countEnc)
                if s_task[1].loc[m, 'position_accuracy'] == 0:
                    s_task[1].loc[m, 'ctl_miss_hit']='missed'
                    s_task[1].loc[m, 'ctl_miss_ws_cs']='missed'
                elif s_task[1].loc[m, 'position_accuracy'] == 1:
                    s_task[1].loc[m, 'ctl_miss_hit']='hit'
                    s_task[1].loc[m, 'ctl_miss_ws_cs']='wrongsource'
                elif s_task[1].loc[m, 'position_accuracy'] == 2:
                    s_task[1].loc[m, 'ctl_miss_hit']='hit'
                    s_task[1].loc[m, 'ctl_miss_ws_cs']='correctsource' 
            for n in s_task[1][s_task[1]['condition']=='CTL'].index:
                countCTL = countCTL + 1
                s_task[1].loc[n, 'trial_type'] = 'CTL'+str(countCTL)
                s_task[1].loc[n, 'ctl_miss_hit']='control'
                s_task[1].loc[n, 'ctl_miss_ws_cs']='control'

            #78 encoding and 39 control trials if full scan
            print('Number of encoding trials:  ', countEnc)
            print('Number of control trials:  ', countCTL)



            #keep only trials for which fMRI data was collected
    # #        s_task[1] = s_task[1][s_task[1]['unscanned']==0]

            s_task[1]['unscanned'] = 0

            #Save vectors of trial labels (e.g., encoding vs control)
            #to label trials for classification analyses
            ttypes1 = s_task[1]['condition']
            
            # Allows user to overwrite files to disk or not 
            
            if not savefiles:
                        #Export Dataframe to events.tsv file    
                s_task[1].to_csv(outTask_dir+'/sub-'+id+'_events.tsv',
                              sep='\t', header=True, index=False)
                ttypes1.to_csv(outTask_dir+'/sub-'+id+'_enco_ctl.tsv',
                               sep='\t', header=True, index=False)
                ttypes2.to_csv(outTask_dir+'/sub-'+id+'_ctl_miss_hit.tsv',
                               sep='\t', header=True, index=False)
                ttypes3.to_csv(outTask_dir+'/sub-'+id+'_ctl_miss_ws_cs.tsv',
                               sep='\t', header=True, index=False)

            ttypes2 = s_task[1]['ctl_miss_hit']


            ttypes3 = s_task[1]['ctl_miss_ws_cs']


            new_events.append([(s_task[0], s_task[1]), ttypes1, ttypes2, ttypes3])
        #from s_task[1] dataframe, create an events dataframe to create a design matrix 
        #that will be inputed into a first-level model in nistats
        ev_cols = ['onset', 'duration', 'trial_type', 'condition', 'ctl_miss_hit', 
                   'ctl_miss_ws_cs', 'trial_number']
        all_events = s_task[1][ev_cols]
        return new_events, all_events
    
    get_new_events(taskfilesdir, outTask_dir)
    
    if __name__ == "__main__":
        main()

# %%
get_new_events(taskfilesdir= "~/../../data/cisl/DATA/cimaq_03-19/derivatives/CIMAQ_fmri_memory/data/task_files/processed",
                   outTask_dir="~/cimaq_memory/NEW_task_files",
                  savefiles=False)
display(newe)
# Out:
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   71
# Number of control trials:   38
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# Number of encoding trials:   78
# Number of control trials:   39
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6ca2004bb9fa> in <module>
#       2                    outTask_dir="~/cimaq_memory/NEW_task_files",
#       3                   savefiles=False)
# ----> 4 display(taskfilesdir, outTask_dir)
#
# NameError: name 'taskfilesdir' is not defined
